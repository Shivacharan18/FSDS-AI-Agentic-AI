# %% [markdown]
# Country gdp analysis using pandas ,sns

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd.read_csv(r'C:\Users\akiti\Downloads\5th - country gdp analysis\DataFrame_ Pandas\data.csv')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Unnamed: 5
# 0            High income        78.9
# 1             Low income         5.9
# 2    Upper middle income        19.1
# 3    Upper middle income        57.2
# ...

# %%
id(df)
# Out:
# 2862655955520

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 195

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'Unnamed: 5'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 6

# %%
len(df.row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19144\2137990623.py in ?()
# ----> 1 len(df.row)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
df.shape

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
#      Unnamed: 5
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# ...

# %%
df.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
#      Unnamed: 5
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# ...

# %%
df.isnull().sum()# it tells about the missing values are present or not,column wise
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# Unnamed: 5       0
# dtype: int64

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  Unnamed: 5
# 0          High income        78.9
# 1           Low income         5.9
# 2  Upper middle income        19.1
# 3  Upper middle income        57.2
# 4          High income        88.0

# %%
df.head
# Out:
# <bound method NDFrame.head of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Unnamed: 5
# 0            High income        78.9
# 1             Low income         5.9
# 2    Upper middle income        19.1
# ...

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Unnamed: 5
# 190  Lower middle income        20.0
# 191  Upper middle income        46.5
# 192           Low income         2.2
# 193  Lower middle income        15.4
# 194           Low income        18.5

# %%
df.tail
# Out:
# <bound method NDFrame.tail of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Unnamed: 5
# 0            High income        78.9
# 1             Low income         5.9
# 2    Upper middle income        19.1
# ...

# %%
df.shape
# Out:
# (195, 6)

# %%
df.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# Unnamed: 5       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
#  5   Unnamed: 5     195 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 9.3+ KB

# %% [markdown]
# # SLICING IN DATAFRAME

# %%
df[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Unnamed: 5
# 0            High income        78.9
# 1             Low income         5.9
# 2    Upper middle income        19.1
# 3    Upper middle income        57.2
# ...

# %%
df[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup  Unnamed: 5
# 194           Low income        18.5
# 193  Lower middle income        15.4
# 192           Low income         2.2
# 191  Upper middle income        46.5
# ...

# %%
df[:11]
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 0                  Aruba         ABW     10.244        78.9000
# 1            Afghanistan         AFG     35.253         5.9000
# 2                 Angola         AGO     45.985        19.1000
# 3                Albania         ALB     12.877        57.2000
# 4   United Arab Emirates         ARE     11.044        88.0000
# 5              Argentina         ARG     17.716        59.9000
# 6                Armenia         ARM     13.308        41.9000
# 7    Antigua and Barbuda         ATG     16.447        63.4000
# 8              Australia         AUS     13.200        83.0000
# 9                Austria         AUT      9.400        80.6188
# 10            Azerbaijan         AZE     18.300        58.7000
#
#             IncomeGroup  Unnamed: 5
# 0           High income     78.9000
# 1            Low income      5.9000
# 2   Upper middle income     19.1000
# 3   Upper middle income     57.2000
# ...

# %%
df[0:200:50]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 0         Aruba         ABW     10.244      78.900000          High income
# 50      Ecuador         ECU     21.070      40.353684  Upper middle income
# 100       Libya         LBY     21.425      16.500000  Upper middle income
# 150       Sudan         SDN     33.477      22.700000  Lower middle income
#
#      Unnamed: 5
# 0     78.900000
# 50    40.353684
# 100   16.500000
# 150   22.700000

# %%
df['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
df[['CountryName','CountryCode']]
# Out:
#               CountryName CountryCode
# 0                   Aruba         ABW
# 1             Afghanistan         AFG
# 2                  Angola         AGO
# 3                 Albania         ALB
# 4    United Arab Emirates         ARE
# ..                    ...         ...
# 190           Yemen, Rep.         YEM
# 191          South Africa         ZAF
# 192      Congo, Dem. Rep.         COD
# 193                Zambia         ZMB
# 194              Zimbabwe         ZWE
#
# [195 rows x 2 columns]

# %%
df[['CountryName','CountryCode','BirthRate']]
# Out:
#               CountryName CountryCode  BirthRate
# 0                   Aruba         ABW     10.244
# 1             Afghanistan         AFG     35.253
# 2                  Angola         AGO     45.985
# 3                 Albania         ALB     12.877
# 4    United Arab Emirates         ARE     11.044
# ..                    ...         ...        ...
# 190           Yemen, Rep.         YEM     32.947
# 191          South Africa         ZAF     20.850
# 192      Congo, Dem. Rep.         COD     42.394
# 193                Zambia         ZMB     40.471
# 194              Zimbabwe         ZWE     35.715
#
# [195 rows x 3 columns]

# %%
df.head(3)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income
#
#    Unnamed: 5
# 0        78.9
# 1         5.9
# 2        19.1

# %% [markdown]
# #descriptive statistics

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers  Unnamed: 5
# count  195.000000     195.000000  195.000000
# mean    21.469928      42.076471   42.076471
# std     10.605467      29.030788   29.030788
# min      7.900000       0.900000    0.900000
# 25%     12.120500      14.520000   14.520000
# 50%     19.680000      41.000000   41.000000
# 75%     29.759500      66.225000   66.225000
# max     49.661000      96.546800   96.546800

# %%
df.describe().T # converts rows to columns and columns to rows
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
# Unnamed: 5     195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468
# Unnamed: 5     96.5468

# %%
df_cat = df[['CountryName','CountryCode','IncomeGroup']]
df_cat
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df_cat.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers  Unnamed: 5
# count  195.000000     195.000000  195.000000
# mean    21.469928      42.076471   42.076471
# std     10.605467      29.030788   29.030788
# min      7.900000       0.900000    0.900000
# 25%     12.120500      14.520000   14.520000
# 50%     19.680000      41.000000   41.000000
# 75%     29.759500      66.225000   66.225000
# max     49.661000      96.546800   96.546800

# %%
df.describe().all()
# Out:
# BirthRate        True
# InternetUsers    True
# Unnamed: 5       True
# dtype: bool

# %%
df.describe(include='all')
# Out:
#        CountryName CountryCode   BirthRate  InternetUsers  IncomeGroup  \
# count          195         195  195.000000     195.000000          195
# unique         195         195         NaN            NaN            4
# top          Aruba         ABW         NaN            NaN  High income
# freq             1           1         NaN            NaN           67
# mean           NaN         NaN   21.469928      42.076471          NaN
# std            NaN         NaN   10.605467      29.030788          NaN
# min            NaN         NaN    7.900000       0.900000          NaN
# 25%            NaN         NaN   12.120500      14.520000          NaN
# 50%            NaN         NaN   19.680000      41.000000          NaN
# 75%            NaN         NaN   29.759500      66.225000          NaN
# max            NaN         NaN   49.661000      96.546800          NaN
#
#         Unnamed: 5
# count   195.000000
# unique         NaN
# top            NaN
# freq           NaN
# ...

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Unnamed: 5
# 0            High income        78.9
# 1             Low income         5.9
# 2    Upper middle income        19.1
# 3    Upper middle income        57.2
# ...

# %%
df.columns = ['a','b','c','d','e','f']

# %%
df.head(1)
# Out:
#        a    b       c     d            e     f
# 0  Aruba  ABW  10.244  78.9  High income  78.9

# %%
df.columns = ['CountryName','CountryCode','BirthRate','InternetUsers','IncomeGroup','empty']

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup  empty
# 0       Aruba         ABW     10.244           78.9  High income   78.9

# %%
df_categoical = df[['CountryName','CountryCode','IncomeGroup']]
df_categoical.head()
# Out:
#             CountryName CountryCode          IncomeGroup
# 0                 Aruba         ABW          High income
# 1           Afghanistan         AFG           Low income
# 2                Angola         AGO  Upper middle income
# 3               Albania         ALB  Upper middle income
# 4  United Arab Emirates         ARE          High income

# %%
df_categoical.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
['CountryName','BirthRate']
# Out:
# ['CountryName', 'BirthRate']

# %%
df[['CountryName','CountryCode','IncomeGroup']]
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  empty
# 0          High income   78.9
# 1           Low income    5.9
# 2  Upper middle income   19.1
# 3  Upper middle income   57.2
# 4          High income   88.0

# %%
#Mathematical operation
df.BirthRate * df.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
#add a column
df['myCalc'] = df.BirthRate * df.InternetUsers

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  empty    myCalc
# 0            High income   78.9  808.2516
# 1             Low income    5.9  207.9927
# 2    Upper middle income   19.1  878.3135
# ...

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'empty', 'myCalc'],
#       dtype='object')

# %%
df = df.drop('myCalc',axis=1)

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  empty
# 0            High income   78.9
# 1             Low income    5.9
# 2    Upper middle income   19.1
# 3    Upper middle income   57.2
# ...

# %%
df.columns[3:4]
# Out:
# Index(['InternetUsers'], dtype='object')

# %%
df.shape
# Out:
# (195, 6)

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
df.InternetUsers<2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
Filter = df.InternetUsers<2

# %%
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[Filter]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income
#
#      empty
# 11     1.3
# 52     0.9
# 55     1.9
# 64     1.6
# 117    1.6
# 127    1.7
# 154    1.7
# 156    1.5
# 172    1.1

# %%
len(df[Filter])
# Out:
# 9

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  empty
# 0            High income   78.9
# 1             Low income    5.9
# 2    Upper middle income   19.1
# 3    Upper middle income   57.2
# ...

# %%
df.BirthRate>40
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
Filter2 = df.BirthRate>40

# %%
Filter2
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
df[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup  empty
# 2    Upper middle income   19.1
# 11            Low income    1.3
# 14            Low income    9.1
# 65            Low income   14.0
# ...

# %%
Filter & Filter2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
df[Filter & Filter2]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup  empty
# 11      Burundi         BDI     44.151            1.3  Low income    1.3
# 127       Niger         NER     49.661            1.7  Low income    1.7
# 156     Somalia         SOM     43.891            1.5  Low income    1.5

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  empty
# 0            High income   78.9
# 1             Low income    5.9
# 2    Upper middle income   19.1
# 3    Upper middle income   57.2
# ...

# %%
df[df.IncomeGroup == 'High income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
#      empty
# 0    78.90
# ...

# %%
# hoe to get unique caterories
df.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
df.IncomeGroup.nunique()
# Out:
# 4

# %%
# Introduction to seadorn. Seaborn is very powerfull visualization (STATISTIC VISULIAISATION) plg in python
import matplotlib.pyplot as plt # visulaization
import seaborn as sns  # distribution visualion
# seaborn is used for advance visualization e.x --> distribution plot, line plot

# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,2

import warnings 
warnings.filterwarnings('ignore') # os error

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  empty
# 0          High income   78.9
# 1           Low income    5.9
# 2  Upper middle income   19.1
# 3  Upper middle income   57.2
# 4          High income   88.0

# %%
df["InternetUsers"]
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
# Distibutions:
vis1 = sns.distplot(df["InternetUsers"])# UNIVARIATE ANALYSIS - statistics 
plt.show(vis1)

# %%
vis2 = sns.displot(df["InternetUsers"])
plt.show(vis2)

# %%
vis3 = sns.distplot(df["InternetUsers"],bins = 15)
plt.show(vis3)

# %%
# Box plots:
vis4 = sns.boxplot(data=df, x="IncomeGroup", y="BirthRate")
plt.show(vis4)

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  empty
# 0            High income   78.9
# 1             Low income    5.9
# 2    Upper middle income   19.1
# 3    Upper middle income   57.2
# ...

# %%
vis5 = sns.lmplot(data = df,x = "InternetUsers", y = "BirthRate",fit_reg = False)# LM = linear model
plt.show()

# %%
vis6 = sns.lmplot(data = df,x = 'InternetUsers', y = 'BirthRate')
plt.show()

# %%
vis6 = sns.lmplot(data = df , x = 'InternetUsers', y = 'BirthRate',fit_reg = False,hue = 'IncomeGroup' ,)# hue : parameter for colou
plt.show()

# %%
vis6 = sns.lmplot(data = df , x = 'InternetUsers', y = 'BirthRate',fit_reg = False,hue = 'IncomeGroup', size = 10) # hue : parameter for colou
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[339], line 1
# ----> 1 vis6 = sns.lmplot(data = df , x = 'InternetUsers', y = 'BirthRate',fit_reg = False,hue = 'IncomeGroup', size = 10) # hue : parameter for colou
#       2 plt.show()
#
# TypeError: lmplot() got an unexpected keyword argument 'size'

# %% [markdown]
# #    In this section we learned
#
# 1> importing data into python
# 2> Dataframe via panda
# 3> exploring datasets: head()tail()info()describe()
# 4> Renaming columns
# 5> subsetting dataframes
# 6> Basic operations with dataframe
# 8> filtering data frames
# 9> seaborn introduction
