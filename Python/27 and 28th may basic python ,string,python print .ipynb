# %% [markdown]
# Operatore's in python

# %% [markdown]
# ![image.png](attachment:43d0e57e-d26b-4de4-ab32-97ca162d175a.png)

# %% [markdown]
# Arithmetic Operators

# %%
x1 , y2 = 5 , 6

# %%
 x1 + y2

# %%
x1 - y2
# Out:
# -1

# %%
x1 * y2
# Out:
# 30

# %%
x1 / y2
# Out:
# 0.8333333333333334

# %%
x1 // y2
# Out:
# 0

# %%
 x1 % y2
# Out:
# 5

# %%
x1 ** y2
# Out:
# 15625

# %%
2**5
# Out:
# 32

# %% [markdown]
# Assigment Operators

# %%
x = 2

# %%
x
# Out:
# 2

# %%
x = x+2

# %%
x
# Out:
# 4

# %%
x += 2

# %%
x
# Out:
# 6

# %%
x *= 2

# %%
x
# Out:
# 12

# %%
x -= 3

# %%
x
# Out:
# 9

# %%
x/=2
x
# Out:
# 4.5

# %%
a , b = 5 , 7

# %%
a
# Out:
# 5

# %%
b
# Out:
# 7

# %% [markdown]
# Unary Operators

# %%
n = 7

# %%
n
# Out:
# 7

# %%
number = float(input("Enter a number: "))

# Mapping using boolean expressions as keys
result = {
    number > 0: "Positive",
    number < 0: "Negative",
    number == 0: "Zero"
}[True]

print("The number is", result)
# Out:
# Enter a number:  -4
# The number is Negative

# %%
m = -(n)

# %%
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %%
n
# Out:
# 7

# %%
-n
# Out:
# -7

# %% [markdown]
# Relational operators

# %%
a = 4
b = 5

# %%
a == b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
# a=b we can't use = operators that means it is  assigning a value

# %%
a == b
# Out:
# False

# %%
a = 10

# %%
a!=b
# Out:
# True

# %%
b = 10

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# False

# %%
b = 7

# %%
a != b
# Out:
# True

# %% [markdown]
# logical operator

# %% [markdown]
# AND , OR ,NOT

# %% [markdown]
# ![image.png](attachment:c9029695-da43-4485-89bc-96a162fe067b.png)

# %%
a = 1
b = 8

# %%
a < 4 and b < 9 # and refer to the table
# Out:
# True

# %%
a < 4 and b < 5
# Out:
# False

# %%
a < 4 or b < 5
# Out:
# True

# %%
a > 8 or b < 5
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x # you can reverse the operation
# Out:
# True

# %%
x = not x

# %%
x
# Out:
# True

# %%
not x
# Out:
# False

# %% [markdown]
# Number system conversion (bit-binary digit)

# %% [markdown]
# binary:base(0-1)-->please divide 15/2& count in reverse order octal:base(0-7) hexadecimal: base(0-9&thena-f)
#
# when you check ip address you will use these format-->cmd-->ipconfig

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
bin(18)
# Out:
# '0b10010'

# %%
0b1010100101
# Out:
# 677

# %%
oct(15)
# Out:
# '0o17'

# %%
oct(10)
# Out:
# '0o12'

# %%
oct(9)
# Out:
# '0o11'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(25)
# Out:
# '0x19'

# %%
0x15
# Out:
# 21

# %% [markdown]
# Swap variable in python

# %% [markdown]
# (a,b=5,6)after swap we should get==>(a,b=6,5)

# %%
a = 5
b = 6

# %%
a = b
b = a

# %%
a,b = b,a

# %%
print(a)
print(b)
# Out:
# 6
# 6

# %%
# in the above scenario we lost value 5
a1 = 7
b1 = 8

# %%
temp = a1
a1 = b1
b1 = temp

# %%
print(a1)
print(b1)
# Out:
# 8
# 7

# %%
a2 = 5
b2 = 6

# %%
# swap two variables formulas
a2 = a2 + b2
b2 = a2 - b2
a2 = a2 - b2

# %%
print(a2)
print(b2)
# Out:
# 6
# 5

# %%
print(0b101)
print(0b110)
# Out:
# 5
# 6

# %%
#but when we use a2 + b2 then we get 11 that means we will get 4 bit which is 1 bit extra 
print(bin(11))
print(0b1011)
# Out:
# 0b1011
# 11

# %%
#there is other way to work using swap variable also which is XOR because it will not waste extra bit 
a2 = a2 ^ b2
b2 = a2 ^ b2
a2 = a2 ^ b2

# %%
print(a2)
print(b2)
# Out:
# 5
# 6

# %%
a2 , b2 = b2 , a2

# %%
print(a2)
print(b2)
# Out:
# 6
# 5
